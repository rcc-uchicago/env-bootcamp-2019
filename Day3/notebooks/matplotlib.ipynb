# %% [markdown]
# # Plotting and Visualization in Python

# %% [markdown]
# There are a number of packages available that support plotting and visualization in python. One of the oldest, and the one in which we will cover in a little more detail is *matplotlib*. It is worth mentioning some of the other common plotting packages in python that are also commonly used.
#
# # Seaborn
# ![](imgs/seaborn.png)
# Seaborn is more or less a skinned and condensed version of matplotlib to create beautiful charts in a few lines of code. Seaborn relies on the matplotlib package to do create the graphics, but what makes it different from matplotlib is the default styles and color palettes, which are designed to be more aesthetically pleasing and modern, and that you can acheive some very sharp looking plots with less complexity.
#
#
# # Bokeh
# ![](imgs/bokeh.png)
#
# Bokeh has strength in its ability to create interactive, web-ready plots, which can be easily output as JSON objects, HTML documents, or interactive web applications. Bokeh also supports streaming and real-time data.

# %% [markdown]
# ![](imgs/matplotlib.png)

# %% [markdown]
# Here we will cover briefly the python plotting library Matplotlib. You will likely rely on this package quite
# often in your futuer python programming feats o visually inspect your data and represent your results graphically, so you should have familiarity with the package's basic usage.
#
# The matplotlib library was designed to closely resemble MATLAB, being capable of producing a wide variety of plots and graphics in different styles, permitting interactivity with your data in various ways. It remains the most widely used python library for plotting. The library is both extermely powerful, which comes with added complexity.
#
# There is a page full of tutorials on the official site at
# https://matplotlib.org/users/tutorials.html.
#
# For a more comprehensive interactive overview of using matplotlib, view the
#  <a href="https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb">Colaboratory link</a> to open an interactive notebook to the matplotlib tutorial that is based on the  <a href="http://shop.oreilly.com/product/0636920034919.do"> Python Data Science Handbook</a>.

# %% [markdown]
# ## Pyplot Example
#
# Let's first review the pyplot submodule.
# This works in a similar way as plotting in Matlab. There's a full tutorial on
# using pyplot available at https://matplotlib.org/users/pyplot_tutorial.html.
#
# An example showing how to use pyplot to generate a basic plot of `sin(x)` is given
# below:

# %%
import matplotlib.pyplot as plt
import numpy as np

# We set up a numpy array covering the range we want to plot.
xvals = np.linspace(-5, 5, 500)

# Now we use these x-values to generate a series of coordinates to plot with
# whatever function we like. In this case we're using the numpy sin function.
# The plot() function is for plotting lines and points in 2D.
plt.plot(xvals, np.sin(xvals))

# We can add axes labels and a plot title.
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Test Plot')

# And finally we display our plot.
plt.show()

# %% [markdown]
# If you embed the above code cell in a python script `sinxplot.py` and run the script from your terminal by issuing `python sinxplot.py`, you would see a window appear with your plot (assuming you have X11 forwarding enabled). You can interact with it in various ways via the menu buttons, such as panning and zooming the plot. There is also a save button which allows you to save the image to various formats. In your current directory where you are running this notebook, there is a python script `sinxplot.py`.

# %% [markdown]
# ## A Multiplot Example

# %% [markdown]
# You can combine several plots together and control the appearance as shown
# in the following code cell, which you could put in your own script `multiplot.py`:

# %%
import matplotlib.pyplot as plt
import numpy as np

# This time will make a figure with two subplots arranged vertically.
# First we initialize our figure
plt.figure()

# Again We set up numpy arrays covering the range we want to plot.
xvals1 = np.linspace(-5, 5, 500)
xvals2 = np.linspace(-5, 5, 20)

# This creates a subplot on a notional grid with 2 rows and 1 column and
# selects the 1st plot (top row).
plt.subplot(211)

# Plot both sin(x) with a blue solid line and cos(x) with red dashed line. We
# can do this with a single plot() command.
plt.plot(xvals1, np.sin(xvals1), 'b-', xvals1, np.cos(xvals1), 'r--')

# And add a legend
plt.legend(["sin", "cos"])

# Select the lower plot
plt.subplot(212)

# Plot sinh(x) and cosh(x) with yellow triangles and green circles connected
# by lines. We do this as four plots - using the denser x value list for the
# lines, and sparser for the points.
# We can use several plot commands to do this.
plt.plot(xvals1, np.sinh(xvals1), 'y-')
plt.plot(xvals2, np.sinh(xvals2), 'y^', label="sinh")
plt.plot(xvals1, np.cosh(xvals1), 'g-')
plt.plot(xvals2, np.cosh(xvals2), 'go', label="cosh")
# Let also fill the area between the curves, but make it semi-transparent
# using the fill_between() function.
plt.fill_between(xvals1, np.cosh(xvals1), np.sinh(xvals1), facecolor='green',
        alpha=0.2)

# Tune a few other settings
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
# Since we've set some labels in the plot commands above we can call
# legend() without any arguments.
plt.legend()

# And finally we display our plot.
plt.show()

# %% [markdown]
# ## Scatter Plot Example
# There is also a function in the matplotlib to create a scatter of points.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 1024
X = np.random.normal(0, 1, n)
Y = np.random.normal(0, 1, n)
T = np.arctan2(Y, X)

plt.axes([0.025, 0.025, 0.95, 0.95])
plt.scatter(X, Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5, 1.5)
plt.xticks(())
plt.ylim(-1.5, 1.5)
plt.yticks(())

plt.show()

# %% [markdown]
# ## Exercise
#
# Using the matplotlib `plt` create a plot of both sinx and cosx overlaid on the same plot. Start from the following code below which has plots just the `cosine` function:
# ```
# import numpy as np
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(8, 5), dpi=80)
# plt.subplot(111)
#
# X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
# C = np.cos(X)
#
# plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
#
# plt.xlim(X.min() * 1.1, X.max() * 1.1)
# plt.ylim(C.min() * 1.1, C.max() * 1.1)
#
# plt.show()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5), dpi=80)
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C = np.cos(X)

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.ylim(C.min() * 1.1, C.max() * 1.1)

plt.show()

# %% [markdown]
# ## Further Reading
#
# If you want to see what kind of plots can be generated, or if you have a
# particular type of plot in mind that you want to generate, you can browse
# through the gallery at https://matplotlib.org/gallery.html. Selecting any
# image will show you the source code used to create it.
